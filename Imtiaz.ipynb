# %% [markdown]
# <a href="https://colab.research.google.com/github/mdimtiazhussains/colab-notebooks/blob/main/Imtiaz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Imtiaz google colab")
# Out:
# Imtiaz google colab

# %% [markdown]
# Sample of problem

# %%
a = 10
b = 20
c = a  + b
print("Sum = ",c)
# Out:
# Sum =  30
